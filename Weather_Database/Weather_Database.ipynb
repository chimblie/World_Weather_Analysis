# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\estel\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\estel\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 733

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1f36d05a40994283f2df97191994047d'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
              
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | nyuksenitsa
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | touros
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | clearwater
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | marzuq
# Processing Record 13 of Set 1 | seymchan
# Processing Record 14 of Set 1 | stornoway
# Processing Record 15 of Set 1 | aljojuca
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | hobyo
# Processing Record 20 of Set 1 | la reforma
# Processing Record 21 of Set 1 | havelock
# Processing Record 22 of Set 1 | henties bay
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | talaya
# Processing Record 26 of Set 1 | tomatlan
# Processing Record 27 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 1 | isiro
# Processing Record 30 of Set 1 | geraldton
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | sinjar
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | beloha
# Processing Record 37 of Set 1 | greenville
# Processing Record 38 of Set 1 | itatinga
# Processing Record 39 of Set 1 | harper
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | antofagasta
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | calabozo
# Processing Record 45 of Set 1 | shelburne
# Processing Record 46 of Set 1 | vila franca do campo
# Processing Record 47 of Set 1 | waipawa
# Processing Record 48 of Set 1 | carikar
# City not found. Skipping...
# Processing Record 49 of Set 1 | kahului
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | udachnyy
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | krasnogvardeyets
# Processing Record 5 of Set 2 | bubaque
# Processing Record 6 of Set 2 | lavrentiya
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | rio gallegos
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | acarau
# Processing Record 12 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | namatanai
# Processing Record 14 of Set 2 | bow island
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | sandwick
# Processing Record 17 of Set 2 | pirenopolis
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | port blair
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | parrita
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | ouango
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | bathsheba
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | fortuna
# Processing Record 29 of Set 2 | radomsko
# Processing Record 30 of Set 2 | vejen
# Processing Record 31 of Set 2 | sutto
# Processing Record 32 of Set 2 | lanxi
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | aksu
# Processing Record 35 of Set 2 | whitehorse
# Processing Record 36 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | maamba
# Processing Record 39 of Set 2 | bandarbeyla
# Processing Record 40 of Set 2 | sobolevo
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | trofors
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | chicama
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | bonthe
# Processing Record 1 of Set 3 | katsuura
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | itarema
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | tezu
# Processing Record 7 of Set 3 | burnie
# Processing Record 8 of Set 3 | leira
# Processing Record 9 of Set 3 | melfort
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | benghazi
# Processing Record 12 of Set 3 | katangli
# Processing Record 13 of Set 3 | port hardy
# Processing Record 14 of Set 3 | broome
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | chapais
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | tashla
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | sibolga
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | aguas formosas
# Processing Record 25 of Set 3 | kushmurun
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | mildura
# Processing Record 28 of Set 3 | sembe
# Processing Record 29 of Set 3 | kalach-na-donu
# Processing Record 30 of Set 3 | busselton
# Processing Record 31 of Set 3 | olinda
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | nuuk
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | nago
# Processing Record 36 of Set 3 | mnogovershinnyy
# Processing Record 37 of Set 3 | jalu
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | kapaa
# Processing Record 40 of Set 3 | shamgarh
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 3 | santa maria
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 3 | kangaatsiaq
# Processing Record 47 of Set 3 | esperance
# Processing Record 48 of Set 3 | bhanvad
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | murgab
# Processing Record 1 of Set 4 | taoudenni
# Processing Record 2 of Set 4 | severo-yeniseyskiy
# Processing Record 3 of Set 4 | zhuhai
# Processing Record 4 of Set 4 | roma
# Processing Record 5 of Set 4 | torbay
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | kisangani
# Processing Record 8 of Set 4 | chanika
# Processing Record 9 of Set 4 | la rioja
# Processing Record 10 of Set 4 | uyuni
# Processing Record 11 of Set 4 | praia
# Processing Record 12 of Set 4 | honningsvag
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | catamarca
# Processing Record 15 of Set 4 | tornio
# Processing Record 16 of Set 4 | svetlogorsk
# Processing Record 17 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 4 | brandon
# Processing Record 19 of Set 4 | mulege
# Processing Record 20 of Set 4 | pisco
# Processing Record 21 of Set 4 | tallahassee
# Processing Record 22 of Set 4 | tura
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | tabukiniberu
# City not found. Skipping...
# Processing Record 25 of Set 4 | kuala terengganu
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | asau
# Processing Record 28 of Set 4 | san jose
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 4 | biak
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | zaria
# Processing Record 35 of Set 4 | komsomolskiy
# Processing Record 36 of Set 4 | ugep
# Processing Record 37 of Set 4 | halifax
# Processing Record 38 of Set 4 | mumford
# Processing Record 39 of Set 4 | portland
# Processing Record 40 of Set 4 | el wasta
# City not found. Skipping...
# Processing Record 41 of Set 4 | tazovskiy
# Processing Record 42 of Set 4 | sri madhopur
# Processing Record 43 of Set 4 | arlit
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | hwange
# Processing Record 46 of Set 4 | yagodnoye
# Processing Record 47 of Set 4 | meulaboh
# Processing Record 48 of Set 4 | ishigaki
# Processing Record 49 of Set 4 | esna
# Processing Record 50 of Set 4 | sergeyevka
# Processing Record 1 of Set 5 | rio tercero
# Processing Record 2 of Set 5 | amapa
# Processing Record 3 of Set 5 | kodiak
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | pundaguitan
# Processing Record 7 of Set 5 | ampanihy
# Processing Record 8 of Set 5 | comodoro rivadavia
# Processing Record 9 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 5 | oranjemund
# Processing Record 11 of Set 5 | acajutla
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | den helder
# Processing Record 14 of Set 5 | tuktoyaktuk
# Processing Record 15 of Set 5 | denia
# Processing Record 16 of Set 5 | guerrero negro
# Processing Record 17 of Set 5 | letterkenny
# Processing Record 18 of Set 5 | penzance
# Processing Record 19 of Set 5 | lakes entrance
# Processing Record 20 of Set 5 | maceio
# Processing Record 21 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 5 | honiara
# Processing Record 23 of Set 5 | inta
# Processing Record 24 of Set 5 | ust-koksa
# Processing Record 25 of Set 5 | wexford
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | te anau
# Processing Record 28 of Set 5 | cockburn town
# Processing Record 29 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 5 | florida
# Processing Record 31 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 5 | nelson bay
# Processing Record 33 of Set 5 | filingue
# Processing Record 34 of Set 5 | zafra
# Processing Record 35 of Set 5 | qaqortoq
# Processing Record 36 of Set 5 | goderich
# Processing Record 37 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 5 | batagay
# Processing Record 40 of Set 5 | matsanga
# City not found. Skipping...
# Processing Record 41 of Set 5 | arman
# Processing Record 42 of Set 5 | necochea
# Processing Record 43 of Set 5 | lashio
# Processing Record 44 of Set 5 | manaure
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | springdale
# Processing Record 47 of Set 5 | havoysund
# Processing Record 48 of Set 5 | maraa
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 50 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 6 | santa cruz de tenerife
# Processing Record 2 of Set 6 | bjorkelangen
# Processing Record 3 of Set 6 | borovskoy
# Processing Record 4 of Set 6 | ankang
# Processing Record 5 of Set 6 | barrow
# Processing Record 6 of Set 6 | chuy
# Processing Record 7 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 6 | darhan
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | contramaestre
# Processing Record 11 of Set 6 | zemio
# Processing Record 12 of Set 6 | fort nelson
# Processing Record 13 of Set 6 | klamath falls
# Processing Record 14 of Set 6 | boca do acre
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | iqaluit
# Processing Record 18 of Set 6 | college
# Processing Record 19 of Set 6 | alekseyevsk
# Processing Record 20 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 6 | caravelas
# Processing Record 22 of Set 6 | hithadhoo
# Processing Record 23 of Set 6 | dukat
# Processing Record 24 of Set 6 | reitoca
# Processing Record 25 of Set 6 | hanna
# Processing Record 26 of Set 6 | sao joao da barra
# Processing Record 27 of Set 6 | pueblo bello
# Processing Record 28 of Set 6 | shubarshi
# Processing Record 29 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 6 | vao
# Processing Record 31 of Set 6 | camana
# Processing Record 32 of Set 6 | khingansk
# Processing Record 33 of Set 6 | arys
# Processing Record 34 of Set 6 | jeremie
# Processing Record 35 of Set 6 | loznica
# Processing Record 36 of Set 6 | san francisco
# Processing Record 37 of Set 6 | saint-joseph
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | le port
# Processing Record 40 of Set 6 | kupino
# Processing Record 41 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 42 of Set 6 | ornskoldsvik
# Processing Record 43 of Set 6 | coihaique
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | narsaq
# Processing Record 46 of Set 6 | los llanos de aridane
# Processing Record 47 of Set 6 | kiunga
# Processing Record 48 of Set 6 | steubenville
# Processing Record 49 of Set 6 | axim
# Processing Record 50 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 1 of Set 7 | bambous virieux
# Processing Record 2 of Set 7 | puerto madryn
# Processing Record 3 of Set 7 | herouville-saint-clair
# Processing Record 4 of Set 7 | kailua
# Processing Record 5 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 7 | verkhnyaya inta
# Processing Record 7 of Set 7 | vitim
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | douentza
# Processing Record 10 of Set 7 | tefe
# Processing Record 11 of Set 7 | namibe
# Processing Record 12 of Set 7 | sarangani
# Processing Record 13 of Set 7 | tartagal
# Processing Record 14 of Set 7 | altamira
# Processing Record 15 of Set 7 | qui nhon
# Processing Record 16 of Set 7 | san patricio
# Processing Record 17 of Set 7 | druzhba
# Processing Record 18 of Set 7 | pakxe
# Processing Record 19 of Set 7 | nikolo-pavlovskoye
# Processing Record 20 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 7 | bokajan
# Processing Record 22 of Set 7 | goundi
# Processing Record 23 of Set 7 | zharkent
# Processing Record 24 of Set 7 | katobu
# Processing Record 25 of Set 7 | balabac
# Processing Record 26 of Set 7 | griffith
# Processing Record 27 of Set 7 | djibo
# Processing Record 28 of Set 7 | puerto leguizamo
# Processing Record 29 of Set 7 | athabasca
# Processing Record 30 of Set 7 | abbeville
# Processing Record 31 of Set 7 | pietersburg
# Processing Record 32 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 7 | swan hill
# Processing Record 34 of Set 7 | koutsouras
# Processing Record 35 of Set 7 | egvekinot
# Processing Record 36 of Set 7 | salalah
# Processing Record 37 of Set 7 | alta floresta
# Processing Record 38 of Set 7 | matara
# Processing Record 39 of Set 7 | bourail
# Processing Record 40 of Set 7 | zabinka
# City not found. Skipping...
# Processing Record 41 of Set 7 | muravlenko
# Processing Record 42 of Set 7 | huilong
# Processing Record 43 of Set 7 | ballina
# Processing Record 44 of Set 7 | jacareacanga
# Processing Record 45 of Set 7 | monte alegre
# Processing Record 46 of Set 7 | marshfield
# Processing Record 47 of Set 7 | general teran
# Processing Record 48 of Set 7 | troitsko-pechorsk
# Processing Record 49 of Set 7 | maxixe
# Processing Record 50 of Set 7 | ixtapa
# Processing Record 1 of Set 8 | dunedin
# Processing Record 2 of Set 8 | lasa
# Processing Record 3 of Set 8 | bamnet narong
# Processing Record 4 of Set 8 | kharan
# Processing Record 5 of Set 8 | mount gambier
# Processing Record 6 of Set 8 | excelsior springs
# Processing Record 7 of Set 8 | berlevag
# Processing Record 8 of Set 8 | mangai
# Processing Record 9 of Set 8 | mahibadhoo
# Processing Record 10 of Set 8 | muroto
# Processing Record 11 of Set 8 | rockhampton
# Processing Record 12 of Set 8 | wanaka
# Processing Record 13 of Set 8 | port macquarie
# Processing Record 14 of Set 8 | lata
# Processing Record 15 of Set 8 | puerto escondido
# Processing Record 16 of Set 8 | numan
# Processing Record 17 of Set 8 | miramar
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | leningradskiy
# Processing Record 20 of Set 8 | urulga
# City not found. Skipping...
# Processing Record 21 of Set 8 | storm lake
# Processing Record 22 of Set 8 | srednekolymsk
# Processing Record 23 of Set 8 | gualeguaychu
# Processing Record 24 of Set 8 | maputo
# Processing Record 25 of Set 8 | ayan
# Processing Record 26 of Set 8 | maltahohe
# Processing Record 27 of Set 8 | hervey bay
# Processing Record 28 of Set 8 | bambanglipuro
# Processing Record 29 of Set 8 | bam
# Processing Record 30 of Set 8 | savannah bight
# Processing Record 31 of Set 8 | ocos
# Processing Record 32 of Set 8 | ilebo
# Processing Record 33 of Set 8 | paamiut
# Processing Record 34 of Set 8 | saldanha
# Processing Record 35 of Set 8 | nakonde
# Processing Record 36 of Set 8 | padang
# Processing Record 37 of Set 8 | ancud
# Processing Record 38 of Set 8 | zhezkazgan
# Processing Record 39 of Set 8 | indri
# Processing Record 40 of Set 8 | houma
# Processing Record 41 of Set 8 | acapulco
# Processing Record 42 of Set 8 | pacific grove
# Processing Record 43 of Set 8 | bengkulu
# Processing Record 44 of Set 8 | george
# Processing Record 45 of Set 8 | quatre cocos
# Processing Record 46 of Set 8 | dongargaon
# Processing Record 47 of Set 8 | la ronge
# Processing Record 48 of Set 8 | tautira
# Processing Record 49 of Set 8 | chilca
# Processing Record 50 of Set 8 | port lincoln
# Processing Record 1 of Set 9 | yumen
# Processing Record 2 of Set 9 | birjand
# Processing Record 3 of Set 9 | kavaratti
# Processing Record 4 of Set 9 | vila
# Processing Record 5 of Set 9 | valga
# Processing Record 6 of Set 9 | glace bay
# Processing Record 7 of Set 9 | kropotkin
# Processing Record 8 of Set 9 | conde
# Processing Record 9 of Set 9 | bodden town
# Processing Record 10 of Set 9 | eyl
# Processing Record 11 of Set 9 | cherskiy
# Processing Record 12 of Set 9 | sao filipe
# Processing Record 13 of Set 9 | doctor juan manuel frutos
# Processing Record 14 of Set 9 | saint-georges
# Processing Record 15 of Set 9 | itapirapua
# Processing Record 16 of Set 9 | manavalakurichi
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | camacha
# Processing Record 19 of Set 9 | sambava
# Processing Record 20 of Set 9 | tigzirt
# Processing Record 21 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 9 | takoradi
# Processing Record 23 of Set 9 | ilulissat
# Processing Record 24 of Set 9 | cocorit
# Processing Record 25 of Set 9 | souillac
# Processing Record 26 of Set 9 | kendari
# Processing Record 27 of Set 9 | grand gaube
# Processing Record 28 of Set 9 | saint anthony
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | najran
# Processing Record 31 of Set 9 | olafsvik
# Processing Record 32 of Set 9 | husavik
# Processing Record 33 of Set 9 | vostok
# Processing Record 34 of Set 9 | marathon
# Processing Record 35 of Set 9 | merauke
# Processing Record 36 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 9 | villa rica
# Processing Record 39 of Set 9 | leshukonskoye
# Processing Record 40 of Set 9 | djambala
# Processing Record 41 of Set 9 | rafai
# Processing Record 42 of Set 9 | segou
# Processing Record 43 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 9 | kibre mengist
# Processing Record 45 of Set 9 | dingle
# Processing Record 46 of Set 9 | ordu
# Processing Record 47 of Set 9 | mar del plata
# Processing Record 48 of Set 9 | santa isabel
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 9 | kilindoni
# Processing Record 1 of Set 10 | karatau
# Processing Record 2 of Set 10 | oktyabrskiy
# Processing Record 3 of Set 10 | anadyr
# Processing Record 4 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 10 | rivadavia
# Processing Record 6 of Set 10 | toora-khem
# Processing Record 7 of Set 10 | madera
# Processing Record 8 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 10 | malanje
# Processing Record 11 of Set 10 | humboldt
# Processing Record 12 of Set 10 | strezhevoy
# Processing Record 13 of Set 10 | road town
# Processing Record 14 of Set 10 | broken hill
# Processing Record 15 of Set 10 | half moon bay
# Processing Record 16 of Set 10 | boa vista
# Processing Record 17 of Set 10 | mantua
# Processing Record 18 of Set 10 | brigantine
# Processing Record 19 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 10 | dwarka
# Processing Record 21 of Set 10 | kloulklubed
# Processing Record 22 of Set 10 | paita
# Processing Record 23 of Set 10 | zarand
# Processing Record 24 of Set 10 | mama
# Processing Record 25 of Set 10 | baykit
# Processing Record 26 of Set 10 | lerwick
# Processing Record 27 of Set 10 | adre
# Processing Record 28 of Set 10 | rockwall
# Processing Record 29 of Set 10 | filadelfia
# Processing Record 30 of Set 10 | pimentel
# Processing Record 31 of Set 10 | contamana
# Processing Record 32 of Set 10 | san jose iturbide
# Processing Record 33 of Set 10 | utete
# Processing Record 34 of Set 10 | ternate
# Processing Record 35 of Set 10 | dalmatovo
# Processing Record 36 of Set 10 | sabha
# Processing Record 37 of Set 10 | sur
# Processing Record 38 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 10 | bandar-e lengeh
# Processing Record 40 of Set 10 | truth or consequences
# Processing Record 41 of Set 10 | zemetchino
# Processing Record 42 of Set 10 | palmer
# Processing Record 43 of Set 10 | malakal
# Processing Record 44 of Set 10 | manokwari
# Processing Record 45 of Set 10 | longyearbyen
# Processing Record 46 of Set 10 | kalevala
# Processing Record 47 of Set 10 | clyde river
# Processing Record 48 of Set 10 | nukus
# Processing Record 49 of Set 10 | lima
# Processing Record 50 of Set 10 | tete
# Processing Record 1 of Set 11 | laurel
# Processing Record 2 of Set 11 | santa maria da boa vista
# Processing Record 3 of Set 11 | bousse
# Processing Record 4 of Set 11 | oistins
# Processing Record 5 of Set 11 | digboi
# Processing Record 6 of Set 11 | cairns
# Processing Record 7 of Set 11 | liberal
# Processing Record 8 of Set 11 | tuensang
# Processing Record 9 of Set 11 | lengshuijiang
# Processing Record 10 of Set 11 | farafangana
# Processing Record 11 of Set 11 | zyryanka
# Processing Record 12 of Set 11 | pangody
# Processing Record 13 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 14 of Set 11 | ponta delgada
# Processing Record 15 of Set 11 | umm lajj
# Processing Record 16 of Set 11 | luoyang
# Processing Record 17 of Set 11 | angoram
# Processing Record 18 of Set 11 | thinadhoo
# Processing Record 19 of Set 11 | the valley
# Processing Record 20 of Set 11 | kpalime
# Processing Record 21 of Set 11 | vila do maio
# Processing Record 22 of Set 11 | clinton
# Processing Record 23 of Set 11 | japura
# Processing Record 24 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 11 | kutum
# Processing Record 26 of Set 11 | portachuelo
# Processing Record 27 of Set 11 | lannion
# Processing Record 28 of Set 11 | thunder bay
# Processing Record 29 of Set 11 | namie
# Processing Record 30 of Set 11 | luang prabang
# Processing Record 31 of Set 11 | havre-saint-pierre
# Processing Record 32 of Set 11 | cabedelo
# Processing Record 33 of Set 11 | jibuti
# Processing Record 34 of Set 11 | constantine
# Processing Record 35 of Set 11 | matagami
# Processing Record 36 of Set 11 | morondava
# Processing Record 37 of Set 11 | port moresby
# Processing Record 38 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 11 | marrakesh
# Processing Record 40 of Set 11 | taltal
# Processing Record 41 of Set 11 | porto novo
# Processing Record 42 of Set 11 | maniitsoq
# Processing Record 43 of Set 11 | rodrigues alves
# Processing Record 44 of Set 11 | sangin
# City not found. Skipping...
# Processing Record 45 of Set 11 | severnyy
# Processing Record 46 of Set 11 | faya
# Processing Record 47 of Set 11 | ostrovnoy
# Processing Record 48 of Set 11 | pitea
# Processing Record 49 of Set 11 | ghanzi
# Processing Record 50 of Set 11 | bilibino
# Processing Record 1 of Set 12 | shestakovo
# Processing Record 2 of Set 12 | waingapu
# Processing Record 3 of Set 12 | aneho
# Processing Record 4 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 5 of Set 12 | de-kastri
# Processing Record 6 of Set 12 | vila velha
# Processing Record 7 of Set 12 | sao jose da coroa grande
# Processing Record 8 of Set 12 | ahipara
# Processing Record 9 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 10 of Set 12 | yar-sale
# Processing Record 11 of Set 12 | mujiayingzi
# Processing Record 12 of Set 12 | garowe
# Processing Record 13 of Set 12 | voh
# Processing Record 14 of Set 12 | ginda
# Processing Record 15 of Set 12 | berbera
# Processing Record 16 of Set 12 | annonay
# Processing Record 17 of Set 12 | kemijarvi
# Processing Record 18 of Set 12 | nanchang
# Processing Record 19 of Set 12 | lazarev
# Processing Record 20 of Set 12 | sumkino
# Processing Record 21 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 12 | phan thiet
# Processing Record 23 of Set 12 | mayo
# Processing Record 24 of Set 12 | chernyshevskiy
# Processing Record 25 of Set 12 | batemans bay
# Processing Record 26 of Set 12 | omsukchan
# Processing Record 27 of Set 12 | vakhsh
# Processing Record 28 of Set 12 | alexandria
# Processing Record 29 of Set 12 | azangaro
# Processing Record 30 of Set 12 | piacabucu
# Processing Record 31 of Set 12 | viedma
# Processing Record 32 of Set 12 | boyolangu
# Processing Record 33 of Set 12 | ocala
# Processing Record 34 of Set 12 | ostersund
# Processing Record 35 of Set 12 | paungde
# Processing Record 36 of Set 12 | manacapuru
# Processing Record 37 of Set 12 | makakilo city
# Processing Record 38 of Set 12 | tabuk
# Processing Record 39 of Set 12 | baruun-urt
# Processing Record 40 of Set 12 | balaguer
# Processing Record 41 of Set 12 | punta de piedra
# Processing Record 42 of Set 12 | constitucion
# Processing Record 43 of Set 12 | jiaojiang
# Processing Record 44 of Set 12 | bahia blanca
# Processing Record 45 of Set 12 | smithers
# Processing Record 46 of Set 12 | phuket
# Processing Record 47 of Set 12 | shache
# Processing Record 48 of Set 12 | pangai
# Processing Record 49 of Set 12 | hovd
# Processing Record 50 of Set 12 | visby
# Processing Record 1 of Set 13 | dudinka
# Processing Record 2 of Set 13 | gari
# Processing Record 3 of Set 13 | el alto
# Processing Record 4 of Set 13 | inverell
# Processing Record 5 of Set 13 | moerai
# Processing Record 6 of Set 13 | suriapet
# Processing Record 7 of Set 13 | baldone
# Processing Record 8 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 13 | nouadhibou
# Processing Record 10 of Set 13 | jilin
# Processing Record 11 of Set 13 | san marcos de tarrazu
# City not found. Skipping...
# Processing Record 12 of Set 13 | agadez
# Processing Record 13 of Set 13 | bol
# Processing Record 14 of Set 13 | miyako
# Processing Record 15 of Set 13 | nishihara
# Processing Record 16 of Set 13 | yamada
# Processing Record 17 of Set 13 | sorong
# Processing Record 18 of Set 13 | playa del carmen
# Processing Record 19 of Set 13 | bayan
# Processing Record 20 of Set 13 | grindavik
# Processing Record 21 of Set 13 | duz
# City not found. Skipping...
# Processing Record 22 of Set 13 | price
# Processing Record 23 of Set 13 | matay
# Processing Record 24 of Set 13 | aykhal
# Processing Record 25 of Set 13 | campo maior
# Processing Record 26 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 13 | maningrida
# Processing Record 28 of Set 13 | nakusp
# Processing Record 29 of Set 13 | nemuro
# Processing Record 30 of Set 13 | steamboat springs
# Processing Record 31 of Set 13 | tshikapa
# Processing Record 32 of Set 13 | covarachia
# City not found. Skipping...
# Processing Record 33 of Set 13 | festus
# Processing Record 34 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 13 | khandyga
# Processing Record 36 of Set 13 | round rock
# Processing Record 37 of Set 13 | sabang
# Processing Record 38 of Set 13 | lakhdenpokhya
# Processing Record 39 of Set 13 | kudahuvadhoo
# Processing Record 40 of Set 13 | vanavara
# Processing Record 41 of Set 13 | puerto el triunfo
# Processing Record 42 of Set 13 | mawlaik
# Processing Record 43 of Set 13 | sigmaringen
# Processing Record 44 of Set 13 | thanatpin
# Processing Record 45 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 13 | muzhi
# Processing Record 47 of Set 13 | kulhudhuffushi
# Processing Record 48 of Set 13 | kerouane
# Processing Record 49 of Set 13 | balkanabat
# Processing Record 50 of Set 13 | general cepeda
# Processing Record 1 of Set 14 | mikkeli
# Processing Record 2 of Set 14 | erzurum
# Processing Record 3 of Set 14 | la playona
# Processing Record 4 of Set 14 | pemangkat
# Processing Record 5 of Set 14 | mbigou
# Processing Record 6 of Set 14 | juneau
# Processing Record 7 of Set 14 | roald
# Processing Record 8 of Set 14 | eureka
# Processing Record 9 of Set 14 | gorontalo
# Processing Record 10 of Set 14 | redencao
# Processing Record 11 of Set 14 | kruisfontein
# Processing Record 12 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 13 of Set 14 | ozernovskiy
# Processing Record 14 of Set 14 | hirna
# Processing Record 15 of Set 14 | buluang
# Processing Record 16 of Set 14 | andujar
# Processing Record 17 of Set 14 | kitale
# Processing Record 18 of Set 14 | mlalo
# Processing Record 19 of Set 14 | togur
# Processing Record 20 of Set 14 | awbari
# Processing Record 21 of Set 14 | vestmannaeyjar
# Processing Record 22 of Set 14 | cardston
# Processing Record 23 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 24 of Set 14 | arawa
# Processing Record 25 of Set 14 | kissidougou
# Processing Record 26 of Set 14 | worland
# Processing Record 27 of Set 14 | neepawa
# Processing Record 28 of Set 14 | flinders
# Processing Record 29 of Set 14 | taihe
# Processing Record 30 of Set 14 | atar
# Processing Record 31 of Set 14 | pauini
# Processing Record 32 of Set 14 | burgeo
# Processing Record 33 of Set 14 | tual
# Processing Record 34 of Set 14 | saint-augustin
# Processing Record 35 of Set 14 | luanda
# Processing Record 36 of Set 14 | chulman
# Processing Record 37 of Set 14 | mercedes
# Processing Record 38 of Set 14 | vavoua
# Processing Record 39 of Set 14 | rundu
# Processing Record 40 of Set 14 | dandong
# Processing Record 41 of Set 14 | marawi
# Processing Record 42 of Set 14 | puerto del rosario
# Processing Record 43 of Set 14 | play cu
# City not found. Skipping...
# Processing Record 44 of Set 14 | kurunegala
# Processing Record 45 of Set 14 | afikpo
# Processing Record 46 of Set 14 | wukari
# Processing Record 47 of Set 14 | kpandae
# Processing Record 48 of Set 14 | oga
# Processing Record 49 of Set 14 | isangel
# Processing Record 50 of Set 14 | khorramshahr
# Processing Record 1 of Set 15 | ceres
# Processing Record 2 of Set 15 | karla
# Processing Record 3 of Set 15 | pangnirtung
# Processing Record 4 of Set 15 | pascagoula
# Processing Record 5 of Set 15 | copiapo
# Processing Record 6 of Set 15 | nador
# Processing Record 7 of Set 15 | almaznyy
# Processing Record 8 of Set 15 | haines junction
# Processing Record 9 of Set 15 | tambura
# Processing Record 10 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 15 | kuching
# Processing Record 12 of Set 15 | jieshi
# Processing Record 13 of Set 15 | lakatoro
# Processing Record 14 of Set 15 | papetoai
# Processing Record 15 of Set 15 | knyaze-volkonskoye
# Processing Record 16 of Set 15 | bundaberg
# Processing Record 17 of Set 15 | formosa do rio preto
# Processing Record 18 of Set 15 | uaua
# Processing Record 19 of Set 15 | kodinsk
# Processing Record 20 of Set 15 | kalmunai
# Processing Record 21 of Set 15 | gat
# Processing Record 22 of Set 15 | ulaanbaatar
# Processing Record 23 of Set 15 | malazgirt
# Processing Record 24 of Set 15 | tabou
# Processing Record 25 of Set 15 | ust-kuyga
# Processing Record 26 of Set 15 | mangan
# Processing Record 27 of Set 15 | dicabisagan
# Processing Record 28 of Set 15 | kibi
# Processing Record 29 of Set 15 | bozhou
# Processing Record 30 of Set 15 | sao geraldo do araguaia
# Processing Record 31 of Set 15 | oriximina
# Processing Record 32 of Set 15 | rawson
# Processing Record 33 of Set 15 | xining
# Processing Record 34 of Set 15 | celestun
# Processing Record 35 of Set 15 | tucumcari
# Processing Record 36 of Set 15 | katakwi
# Processing Record 37 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 38 of Set 15 | lahij
# Processing Record 39 of Set 15 | kroya
# Processing Record 40 of Set 15 | kapustin yar
# Processing Record 41 of Set 15 | bontang
# Processing Record 42 of Set 15 | fukue
# Processing Record 43 of Set 15 | akureyri
# Processing Record 44 of Set 15 | airai
# Processing Record 45 of Set 15 | diamantino
# Processing Record 46 of Set 15 | praia da vitoria
# Processing Record 47 of Set 15 | emerald
# Processing Record 48 of Set 15 | beringovskiy
# Processing Record 49 of Set 15 | sechura
# Processing Record 50 of Set 15 | koraput
# Processing Record 1 of Set 16 | bushehr
# Processing Record 2 of Set 16 | konevo
# Processing Record 3 of Set 16 | french harbor
# Processing Record 4 of Set 16 | nantucket
# Processing Record 5 of Set 16 | kalmanka
# Processing Record 6 of Set 16 | tessalit
# Processing Record 7 of Set 16 | fuling
# Processing Record 8 of Set 16 | invercargill
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Khatanga      RU  71.9667  102.5000    -19.53        99          97
# 1     Nyuksenitsa      RU  60.4128   44.2397     24.76        97         100
# 2          Touros      BR  -5.1989  -35.4608     86.65        60         100
# 3         Ushuaia      AR -54.8000  -68.3000     64.02        51          40
# 4        Victoria      HK  22.2855  114.1577     66.38        80          81
# 5            Lebu      CL -37.6167  -73.6500     63.63        63           0
# 6     Provideniya      RU  64.3833 -173.3000      9.23        94          56
# 7        Hermanus      ZA -34.4187   19.2345     72.81        62           0
# 8      Clearwater      US  27.9659  -82.8001     76.14        82           0
# 9  Severo-Kurilsk      RU  50.6789  156.1250     28.54        93         100
#
#    Wind Speed Current Description
# 0        3.71     overcast clouds
# 1        5.55     overcast clouds
# 2       15.32     overcast clouds
# 3        5.75    scattered clouds
# 4       15.01       broken clouds
# 5       20.62           clear sky
# 6       12.28       broken clouds
# 7       10.54           clear sky
# 8        3.44           clear sky
# 9       44.16                snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = city_data_df.iloc[:,[0,1,2,3,4,5,6,7,8,]]

# Recreate the DataFrame by using the new column order
city_data_df = new_column_order 

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Khatanga      RU  71.9667  102.5000    -19.53        99          97
# 1     Nyuksenitsa      RU  60.4128   44.2397     24.76        97         100
# 2          Touros      BR  -5.1989  -35.4608     86.65        60         100
# 3         Ushuaia      AR -54.8000  -68.3000     64.02        51          40
# 4        Victoria      HK  22.2855  114.1577     66.38        80          81
# 5            Lebu      CL -37.6167  -73.6500     63.63        63           0
# 6     Provideniya      RU  64.3833 -173.3000      9.23        94          56
# 7        Hermanus      ZA -34.4187   19.2345     72.81        62           0
# 8      Clearwater      US  27.9659  -82.8001     76.14        82           0
# 9  Severo-Kurilsk      RU  50.6789  156.1250     28.54        93         100
#
#    Wind Speed Current Description
# 0        3.71     overcast clouds
# 1        5.55     overcast clouds
# 2       15.32     overcast clouds
# 3        5.75    scattered clouds
# 4       15.01       broken clouds
# 5       20.62           clear sky
# 6       12.28       broken clouds
# 7       10.54           clear sky
# 8        3.44           clear sky
# 9       44.16                snow

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
out_file_name = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(out_file_name)
