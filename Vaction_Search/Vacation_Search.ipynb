# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")

# Display sample data
city_data_df.head(5)
# Out:
#    Unnamed: 0         City Country      Lat       Lng  Max Temp  Humidity  \
# 0           0     Khatanga      RU  71.9667  102.5000    -19.53        99
# 1           1  Nyuksenitsa      RU  60.4128   44.2397     24.76        97
# 2           2       Touros      BR  -5.1989  -35.4608     86.65        60
# 3           3      Ushuaia      AR -54.8000  -68.3000     64.02        51
# 4           4     Victoria      HK  22.2855  114.1577     66.38        80
#
#    Cloudiness  Wind Speed Current Description
# 0          97        3.71     overcast clouds
# 1         100        5.55     overcast clouds
# 2         100       15.32     overcast clouds
# 3          40        5.75    scattered clouds
# 4          81       15.01       broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your vacation?"))
max_temp = float(input("What is the maximum temperature you would like for your vacation?"))
# Out:
# What is the minimum temperature you would like for your vacation?70
# What is the maximum temperature you would like for your vacation?90

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]

# Display sample data
preferred_cities_df.head(10)
# Out:
#     Unnamed: 0        City Country      Lat       Lng  Max Temp  Humidity  \
# 2            2      Touros      BR  -5.1989  -35.4608     86.65        60
# 7            7    Hermanus      ZA -34.4187   19.2345     72.81        62
# 8            8  Clearwater      US  27.9659  -82.8001     76.14        82
# 10          10      Marzuq      YE  14.4000   46.4667     72.57        43
# 17          17       Hobyo      SO   5.3505   48.5268     77.13        65
# 21          21     Rikitea      PF -23.1203 -134.9692     78.75        73
# 24          24    Tomatlan      MX  19.9333 -105.2500     72.28        45
# 25          25       Isiro      CD   2.7739   27.6160     89.10        28
# 26          26   Geraldton      AU -28.7667  114.6000     75.61        73
# 27          27    Cidreira      BR -30.1811  -50.2056     80.82        69
#
#     Cloudiness  Wind Speed Current Description
# 2          100       15.32     overcast clouds
# 7            0       10.54           clear sky
# 8            0        3.44           clear sky
# 10           6        8.12           clear sky
# 17          96       18.88     overcast clouds
# 21          10       17.13           clear sky
# 24          92        1.43     overcast clouds
# 25          88        3.67     overcast clouds
# 26          47        6.91    scattered clouds
# 27           4        9.66           clear sky

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.head()
# Out:
#     Unnamed: 0        City Country      Lat      Lng  Max Temp  Humidity  \
# 2            2      Touros      BR  -5.1989 -35.4608     86.65        60
# 7            7    Hermanus      ZA -34.4187  19.2345     72.81        62
# 8            8  Clearwater      US  27.9659 -82.8001     76.14        82
# 10          10      Marzuq      YE  14.4000  46.4667     72.57        43
# 17          17       Hobyo      SO   5.3505  48.5268     77.13        65
#
#     Cloudiness  Wind Speed Current Description
# 2          100       15.32     overcast clouds
# 7            0       10.54           clear sky
# 8            0        3.44           clear sky
# 10           6        8.12           clear sky
# 17          96       18.88     overcast clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %%
hotel_df
# Out:
#               City Country  Max Temp Current Description      Lat       Lng
# 2           Touros      BR     86.65     overcast clouds  -5.1989  -35.4608
# 7         Hermanus      ZA     72.81           clear sky -34.4187   19.2345
# 8       Clearwater      US     76.14           clear sky  27.9659  -82.8001
# 10          Marzuq      YE     72.57           clear sky  14.4000   46.4667
# 17           Hobyo      SO     77.13     overcast clouds   5.3505   48.5268
# ..             ...     ...       ...                 ...      ...       ...
# 676        Bontang      ID     74.46          light rain   0.1333  117.5000
# 680     Diamantino      BR     84.63       broken clouds -14.4086  -56.4461
# 682        Emerald      AU     81.34     overcast clouds -23.5333  148.1667
# 684        Sechura      PE     85.03    scattered clouds  -5.5569  -80.8222
# 688  French Harbor      HN     82.40          few clouds  16.3500  -86.4333
#
# [272 rows x 6 columns]

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = "" 

# Display sample data
hotel_df
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 2           Touros      BR     86.65     overcast clouds  -5.1989  -35.4608
# 7         Hermanus      ZA     72.81           clear sky -34.4187   19.2345
# 8       Clearwater      US     76.14           clear sky  27.9659  -82.8001
# 10          Marzuq      YE     72.57           clear sky  14.4000   46.4667
# 17           Hobyo      SO     77.13     overcast clouds   5.3505   48.5268
# ..             ...     ...       ...                 ...      ...       ...
# 676        Bontang      ID     74.46          light rain   0.1333  117.5000
# 680     Diamantino      BR     84.63       broken clouds -14.4086  -56.4461
# 682        Emerald      AU     81.34     overcast clouds -23.5333  148.1667
# 684        Sechura      PE     85.03    scattered clouds  -5.5569  -80.8222
# 688  French Harbor      HN     82.40          few clouds  16.3500  -86.4333
#
#     Hotel Name
# 2
# 7
# 8
# 10
# 17
# ..         ...
# 676
# 680
# 682
# 684
# 688
#
# [272 rows x 7 columns]

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url,params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] =  name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Touros - nearest hotel: Pousada Atlântico
# Hermanus - nearest hotel: Aloe guest house
# Clearwater - nearest hotel: The Fort Harrison Hotel
# Marzuq - nearest hotel: No hotel found
# Hobyo - nearest hotel: No hotel found
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# Isiro - nearest hotel: Hôtel Magbetu
# Geraldton - nearest hotel: Ocean Centre Hotel
# Cidreira - nearest hotel: Hotel Castelo
# Georgetown - nearest hotel: Page 63 hostel
# Beloha - nearest hotel: No hotel found
# Itatinga - nearest hotel: No hotel found
# Harper - nearest hotel: No hotel found
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Antofagasta - nearest hotel: Hotel Colón
# Calabozo - nearest hotel: Hotel Plaza Real
# Kahului - nearest hotel: Maui Seaside Hotel
# San Cristobal - nearest hotel: Terra Sur
# Bubaque - nearest hotel: Chez Julio
# Vaini - nearest hotel: Keleti International Resort
# Rio Gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# Acarau - nearest hotel: No hotel found
# Namatanai - nearest hotel: Namatanai Hotel
# Pirenopolis - nearest hotel: Pousada das Cavalhadas
# Avarua - nearest hotel: Paradise Inn
# Carnarvon - nearest hotel: No hotel found
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Parrita - nearest hotel: Hotel Paraíso Carlisa
# Port Elizabeth - nearest hotel: Waterford Hotel
# Atuona - nearest hotel: Pearl Resort
# Bathsheba - nearest hotel: Atlantis Hotel
# Butaritari - nearest hotel: No hotel found
# Maamba - nearest hotel: No hotel found
# Bandarbeyla - nearest hotel: No hotel found
# Hilo - nearest hotel: Dolphin Bay Hotel
# Mahebourg - nearest hotel: Grand Bel Air
# Bredasdorp - nearest hotel: Victoria Hotel
# Bonthe - nearest hotel: No hotel found
# Itarema - nearest hotel: Pousada Oásis
# Port Alfred - nearest hotel: No hotel found
# Adrar - nearest hotel: No hotel found
# Cape Town - nearest hotel: Townhouse Hotel
# Sibolga - nearest hotel: Hotel Prima Indah
# Aguas Formosas - nearest hotel: No hotel found
# Olinda - nearest hotel: Fidji Motel
# Kapaa - nearest hotel: Pono Kai Resort
# Castro - nearest hotel: Hotel Central Palace
# Santa Maria - nearest hotel: Hotel Morotin
# Bhanvad - nearest hotel: No hotel found
# Taoudenni - nearest hotel: No hotel found
# Kisangani - nearest hotel: Le Chalet
# Chanika - nearest hotel: Handeni Country Villa
# Praia - nearest hotel: Casa Sodadi
# Saint-Philippe - nearest hotel: Le Baril
# Catamarca - nearest hotel: Hotel de Turismo
# Brandon - nearest hotel: Brandon Motor Lodge
# Pisco - nearest hotel: La Portada
# East London - nearest hotel: No hotel found
# Kuala Terengganu - nearest hotel: Uncle Homestay
# Faanui - nearest hotel: Oa Oa Lodge
# Biak - nearest hotel: No hotel found
# Alofi - nearest hotel: No hotel found
# Mumford - nearest hotel: No hotel found
# Arlit - nearest hotel: No hotel found
# Hwange - nearest hotel: No hotel found
# Meulaboh - nearest hotel: Hotel Meuligou
# Rio Tercero - nearest hotel: hotel Argentino
# Amapa - nearest hotel: No hotel found
# Pundaguitan - nearest hotel: No hotel found
# Ampanihy - nearest hotel: Hotel restaurant Angora
# Comodoro Rivadavia - nearest hotel: No hotel found
# Acajutla - nearest hotel: Hotel Lara
# Maceio - nearest hotel: Maceió Hostel e Pousada
# Honiara - nearest hotel: King Solomon Hotel
# Cockburn Town - nearest hotel: The Salt Raker Inn
# Florida - nearest hotel: No hotel found
# Nelson Bay - nearest hotel: No hotel found
# Necochea - nearest hotel: Cabañas Río Quequén
# Manaure - nearest hotel: hotel palaima
# Saint-Pierre - nearest hotel: Tropic Hotel
# Maraa - nearest hotel: No hotel found
# Arraial Do Cabo - nearest hotel: No hotel found
# Chuy - nearest hotel: Alerces
# Contramaestre - nearest hotel: Caribeño
# Boca Do Acre - nearest hotel: No hotel found
# Port-Gentil - nearest hotel: Tara-Mé
# Caravelas - nearest hotel: Pousada dos Navegantes
# Hithadhoo - nearest hotel: Pebbles Inn
# Reitoca - nearest hotel: No hotel found
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Pueblo Bello - nearest hotel: No hotel found
# Vao - nearest hotel: Nataiwatch
# Camana - nearest hotel: Caja Arequipa
# Jeremie - nearest hotel: Delivrance Hotel
# Saint-Joseph - nearest hotel: No hotel found
# Le Port - nearest hotel: No hotel found
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Kiunga - nearest hotel: No hotel found
# Axim - nearest hotel: Axim Beach Hotel
# Bambous Virieux - nearest hotel: No hotel found
# Puerto Madryn - nearest hotel: Hotel Gran Palace
# Kailua - nearest hotel: No hotel found
# Cayenne - nearest hotel: Central Hôtel
# Tefe - nearest hotel: Hotel Montecarlo
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Sarangani - nearest hotel: No hotel found
# Altamira - nearest hotel: Hotel Vale do Xingu
# Qui Nhon - nearest hotel: No hotel found
# Pakxe - nearest hotel: Residence Sisouk
# Katobu - nearest hotel: No hotel found
# Balabac - nearest hotel: No hotel found
# Salalah - nearest hotel: Muscat International Hotel
# Alta Floresta - nearest hotel: Villas Hotel
# Matara - nearest hotel: Villa Palm Breeze
# Bourail - nearest hotel: Hôtel Restaurant La Néra
# Ballina - nearest hotel: Ballina Beach Resort
# Jacareacanga - nearest hotel: Hotel São Cristovão
# Monte Alegre - nearest hotel: No hotel found
# Maxixe - nearest hotel: Hotel Herry
# Bamnet Narong - nearest hotel: Racha & Glenn Andersson
# Mangai - nearest hotel: No hotel found
# Mahibadhoo - nearest hotel: Coral View Inn
# Rockhampton - nearest hotel: Rockhampton Plaza
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Miramar - nearest hotel: El Palacio Sports Hotel
# Mount Isa - nearest hotel: Ibis Styles
# Gualeguaychu - nearest hotel: Praga
# Maputo - nearest hotel: Mozaika
# Hervey Bay - nearest hotel: Hervey Bay Hotel
# Bambanglipuro - nearest hotel: No hotel found
# Savannah Bight - nearest hotel: La Giralda
# Ocos - nearest hotel: No hotel found
# Ilebo - nearest hotel: Hôtel des Palmes
# Saldanha - nearest hotel: Hoedjesbaai
# Padang - nearest hotel: losmen Surya
# Acapulco - nearest hotel: Hotel del Valle
# Bengkulu - nearest hotel: Dena Hotel
# Quatre Cocos - nearest hotel: Horisun
# Tautira - nearest hotel: No hotel found
# Chilca - nearest hotel: Hotel Benvenuto
# Kavaratti - nearest hotel: No hotel found
# Conde - nearest hotel: Paladino
# Bodden Town - nearest hotel: Turtle Nest Inn
# Eyl - nearest hotel: فندق ايل دابي
# Sao Filipe - nearest hotel: Bela Vista
# Saint-Georges - nearest hotel: Deyna's City Inn
# Itapirapua - nearest hotel: No hotel found
# Manavalakurichi - nearest hotel: No hotel found
# Kavieng - nearest hotel: Kavieng Hotel
# Sambava - nearest hotel: Royal Sava Hôtel
# Takoradi - nearest hotel: Hillcrest
# Souillac - nearest hotel: Hotel SkylineInn
# Kendari - nearest hotel: City Hotel Kendari
# Grand Gaube - nearest hotel: Coco Villa
# Najran - nearest hotel: No hotel found
# Merauke - nearest hotel: No hotel found
# Djambala - nearest hotel: No hotel found
# Kibre Mengist - nearest hotel: Ochee Hotel
# Dingle - nearest hotel: No hotel found
# Mar Del Plata - nearest hotel: Nuevo Ostende
# Santa Isabel - nearest hotel: No hotel found
# Kilindoni - nearest hotel: Ibizza Inn
# Rivadavia - nearest hotel: Hotel Pasambay
# Malanje - nearest hotel: dom Fausto
# Road Town - nearest hotel: No hotel found
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Kloulklubed - nearest hotel: The Adventures Inn
# Paita - nearest hotel: Victor's
# Adre - nearest hotel: No hotel found
# Pimentel - nearest hotel: Hospedaje Calle del Sol
# Contamana - nearest hotel: No hotel found
# Utete - nearest hotel: No hotel found
# Ternate - nearest hotel: Boulivard ternate
# Malakal - nearest hotel: No hotel found
# Manokwari - nearest hotel: Hotel Arfak
# Lima - nearest hotel: Hotel Peach Garden
# Tete - nearest hotel: Zambezi Hotel
# Santa Maria Da Boa Vista - nearest hotel: No hotel found
# Oistins - nearest hotel: The Abidah By Accra
# Cairns - nearest hotel: Cairns Queens Court Accommodation
# Farafangana - nearest hotel: Le Concombre Masqué
# Angoram - nearest hotel: No hotel found
# Thinadhoo - nearest hotel: No hotel found
# The Valley - nearest hotel: CeBlue
# Vila Do Maio - nearest hotel: Residencial Jardins De Maio
# Japura - nearest hotel: No hotel found
# Kutum - nearest hotel: No hotel found
# Portachuelo - nearest hotel: No hotel found
# Jibuti - nearest hotel: No hotel found
# Morondava - nearest hotel: Hotel Sharon Menabe
# Port Moresby - nearest hotel: The Sanctuary Hotel and Spa
# Taltal - nearest hotel: Hostería Taltal
# Porto Novo - nearest hotel: Hôtel 6500 CFA
# Rodrigues Alves - nearest hotel: No hotel found
# Ghanzi - nearest hotel: Ghanzi farmhouse
# Waingapu - nearest hotel: HOTEL SANDLEWOOD
# Aneho - nearest hotel: Mater Christi
# Vila Velha - nearest hotel: Hotel Prainha
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Ahipara - nearest hotel: YHA Ahipara
# Garowe - nearest hotel: Red Sea
# Voh - nearest hotel: Le Vook
# Berbera - nearest hotel: Al Madina Hotel
# Phan Thiet - nearest hotel: Khách sạn Cà Ty
# Piacabucu - nearest hotel: O Leão
# Viedma - nearest hotel: Níjar
# Boyolangu - nearest hotel: No hotel found
# Ocala - nearest hotel: Hilton Garden Inn
# Paungde - nearest hotel: No hotel found
# Manacapuru - nearest hotel: Novo Hotel
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Tabuk - nearest hotel: Davidson Hotel
# Constitucion - nearest hotel: Hostal Alameda
# Bahia Blanca - nearest hotel: Hotel Austral Bahía
# Phuket - nearest hotel: Amanpuri
# Pangai - nearest hotel: Billy's Place
# El Alto - nearest hotel: No hotel found
# Moerai - nearest hotel: Manotel Rurutu
# Bol - nearest hotel: No hotel found
# Sorong - nearest hotel: Hotel Membramo Marina
# Playa Del Carmen - nearest hotel: Wabi hotel
# Campo Maior - nearest hotel: Hotel Pousada do Lago
# Maningrida - nearest hotel: No hotel found
# Tshikapa - nearest hotel: Hôtel TSHAMUNTU
# Sabang - nearest hotel: Sabang Hill
# Kudahuvadhoo - nearest hotel: No hotel found
# Thanatpin - nearest hotel: No hotel found
# Kulhudhuffushi - nearest hotel: No hotel found
# Kerouane - nearest hotel: No hotel found
# La Playona - nearest hotel: No hotel found
# Pemangkat - nearest hotel: Hotel Kelapa Gading
# Mbigou - nearest hotel: No hotel found
# Gorontalo - nearest hotel: Grand City Hotel
# Redencao - nearest hotel: No hotel found
# Buluang - nearest hotel: No hotel found
# Mlalo - nearest hotel: No hotel found
# Arawa - nearest hotel: No hotel found
# Kissidougou - nearest hotel: Mantisse
# Atar - nearest hotel: فندق سكليل
# Pauini - nearest hotel: No hotel found
# Tual - nearest hotel: Suita
# Luanda - nearest hotel: Hotel Forum
# Mercedes - nearest hotel: Gran Hotel Mercedes
# Vavoua - nearest hotel: Hôtel Sougoun
# Kurunegala - nearest hotel: Rock Hotel
# Wukari - nearest hotel: No hotel found
# Isangel - nearest hotel: Tanna Lodge
# Copiapo - nearest hotel: Hotel Il Riposo
# Tambura - nearest hotel: No hotel found
# Kuching - nearest hotel: Hotel Samudera
# Lakatoro - nearest hotel: No hotel found
# Papetoai - nearest hotel: Ancien Intercontinental (fermé)
# Bundaberg - nearest hotel: Young Australian Hotel
# Formosa Do Rio Preto - nearest hotel: Pousada Universo - Formosa do Rio Preto BA
# Uaua - nearest hotel: Hotel Uauá
# Kalmunai - nearest hotel: Saji new food
# Tabou - nearest hotel: hôtel le rochet
# Dicabisagan - nearest hotel: No hotel found
# Kibi - nearest hotel: Gold City Hotel
# Sao Geraldo Do Araguaia - nearest hotel: Tomazi Hotel
# Oriximina - nearest hotel: No hotel found
# Rawson - nearest hotel: Hotel Deportivo
# Celestun - nearest hotel: Hotel Flamingo Playa
# Katakwi - nearest hotel: No hotel found
# Lahij - nearest hotel: No hotel found
# Kroya - nearest hotel: Setia Hotel
# Bontang - nearest hotel: Hotel Sederhana
# Diamantino - nearest hotel: Hotel kayaby
# Emerald - nearest hotel: Emerald Central Hotel
# Sechura - nearest hotel: Hospedaje Claritza
# French Harbor - nearest hotel: Fantasy Island
#               City Country  Max Temp Current Description      Lat       Lng  \
# 2           Touros      BR     86.65     overcast clouds  -5.1989  -35.4608
# 7         Hermanus      ZA     72.81           clear sky -34.4187   19.2345
# 8       Clearwater      US     76.14           clear sky  27.9659  -82.8001
# 10          Marzuq      YE     72.57           clear sky  14.4000   46.4667
# 17           Hobyo      SO     77.13     overcast clouds   5.3505   48.5268
# ..             ...     ...       ...                 ...      ...       ...
# 676        Bontang      ID     74.46          light rain   0.1333  117.5000
# 680     Diamantino      BR     84.63       broken clouds -14.4086  -56.4461
# 682        Emerald      AU     81.34     overcast clouds -23.5333  148.1667
# 684        Sechura      PE     85.03    scattered clouds  -5.5569  -80.8222
# 688  French Harbor      HN     82.40          few clouds  16.3500  -86.4333
#
#                   Hotel Name
# 2          Pousada Atlântico
# 7           Aloe guest house
# 8    The Fort Harrison Hotel
# 10            No hotel found
# 17            No hotel found
# ..                       ...
# 676          Hotel Sederhana
# 680             Hotel kayaby
# 682    Emerald Central Hotel
# 684       Hospedaje Claritza
# 688           Fantasy Island
#
# [272 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[(hotel_df["Hotel Name"]!="No hotel found")]

# Display sample data
clean_hotel_df.head(10)
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 2         Touros      BR     86.65     overcast clouds  -5.1989  -35.4608
# 7       Hermanus      ZA     72.81           clear sky -34.4187   19.2345
# 8     Clearwater      US     76.14           clear sky  27.9659  -82.8001
# 21       Rikitea      PF     78.75           clear sky -23.1203 -134.9692
# 24      Tomatlan      MX     72.28     overcast clouds  19.9333 -105.2500
# 25         Isiro      CD     89.10     overcast clouds   2.7739   27.6160
# 26     Geraldton      AU     75.61    scattered clouds -28.7667  114.6000
# 27      Cidreira      BR     80.82           clear sky -30.1811  -50.2056
# 29    Georgetown      MY     78.73    scattered clouds   5.4112  100.3354
# 36  Puerto Ayora      EC     84.16    scattered clouds  -0.7393  -90.3518
#
#                               Hotel Name
# 2                      Pousada Atlântico
# 7                       Aloe guest house
# 8                The Fort Harrison Hotel
# 21                  Chez Bianca & Benoit
# 24         Hotel Hacienda Vieja Tomatlan
# 25                         Hôtel Magbetu
# 26                    Ocean Centre Hotel
# 27                         Hotel Castelo
# 29                        Page 63 hostel
# 36  Hostal La Mirada De Solitario George

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_file)

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
import geoviews as gv
city = gv.Dataset(clean_hotel_df,kdims = ["City", "Country", "Max Temp"])
points = city.to(gv.Points,["Lng","Lat"],["City", "Max Temp", "Hotel Name","Country", "Current Description"])
tiles = gv.tile_sources.Wikipedia

# Display the map
tiles*points.opts(color = "City", size = "Max Temp", tools = ["hover"],width = 900, height = 600, cmap = "Category10")
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)

# %%
pip install geoviews
# Out:
# Collecting geoviews
#   Using cached geoviews-1.9.6-py2.py3-none-any.whl (508 kB)
# Requirement already satisfied: panel in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (0.13.1)
# Requirement already satisfied: param in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (1.12.0)
# Requirement already satisfied: bokeh<2.5,>=2.4.0 in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (2.4.3)
# Requirement already satisfied: holoviews>=1.14.2 in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (1.15.0)
# Requirement already satisfied: packaging in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (21.3)
# Requirement already satisfied: shapely in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (1.8.4)
# Requirement already satisfied: numpy in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (1.21.5)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\estel\anaconda3\lib\site-packages (from geoviews) (0.21.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\estel\anaconda3\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (6.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\estel\anaconda3\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (4.3.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\estel\anaconda3\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (2.11.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\estel\anaconda3\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\estel\anaconda3\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (9.2.0)
# Requirement already satisfied: pyproj>=3.0.0 in c:\users\estel\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.4.1)
# Requirement already satisfied: pyshp>=2.1 in c:\users\estel\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.1.3)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\estel\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.5.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\estel\anaconda3\lib\site-packages (from holoviews>=1.14.2->geoviews) (2.0.2)
# Requirement already satisfied: colorcet in c:\users\estel\anaconda3\lib\site-packages (from holoviews>=1.14.2->geoviews) (3.0.0)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\estel\anaconda3\lib\site-packages (from holoviews>=1.14.2->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\estel\anaconda3\lib\site-packages (from packaging->geoviews) (3.0.9)
# Requirement already satisfied: bleach in c:\users\estel\anaconda3\lib\site-packages (from panel->geoviews) (4.1.0)
# Requirement already satisfied: markdown in c:\users\estel\anaconda3\lib\site-packages (from panel->geoviews) (3.3.4)
# Requirement already satisfied: requests in c:\users\estel\anaconda3\lib\site-packages (from panel->geoviews) (2.28.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\estel\anaconda3\lib\site-packages (from panel->geoviews) (0.4.8)
# Requirement already satisfied: setuptools in c:\users\estel\anaconda3\lib\site-packages (from panel->geoviews) (63.4.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\estel\anaconda3\lib\site-packages (from panel->geoviews) (4.64.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\estel\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<2.5,>=2.4.0->geoviews) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\estel\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\estel\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\estel\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\estel\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\estel\anaconda3\lib\site-packages (from pandas>=0.20.0->holoviews>=1.14.2->geoviews) (2022.1)
# Requirement already satisfied: certifi in c:\users\estel\anaconda3\lib\site-packages (from pyproj>=3.0.0->cartopy>=0.18.0->geoviews) (2022.9.14)
# Requirement already satisfied: colorama in c:\users\estel\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel->geoviews) (0.4.5)
# Requirement already satisfied: webencodings in c:\users\estel\anaconda3\lib\site-packages (from bleach->panel->geoviews) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\estel\anaconda3\lib\site-packages (from bleach->panel->geoviews) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\estel\anaconda3\lib\site-packages (from requests->panel->geoviews) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\estel\anaconda3\lib\site-packages (from requests->panel->geoviews) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\estel\anaconda3\lib\site-packages (from requests->panel->geoviews) (2.0.4)
# Installing collected packages: geoviews
# Successfully installed geoviews-1.9.6
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install cartopy
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\estel\anaconda3
#
#   added / updated specs:
#     - cartopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cartopy-0.21.1             |   py39hb6e7958_0         1.6 MB
#     conda-23.1.0               |   py39haa95532_0         946 KB
#     geos-3.8.0                 |       h33f27b4_0         905 KB
#     proj-8.2.1                 |       h5ed7ab8_0         2.4 MB
#     pyproj-3.4.1               |   py39hb622704_0         393 KB
#     pyshp-2.1.3                |     pyhd3eb1b0_0          37 KB
#     shapely-1.8.4              |   py39h9064783_0         364 KB
#     ------------------------------------------------------------
#                                            Total:         6.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cartopy            pkgs/main/win-64::cartopy-0.21.1-py39hb6e7958_0
#   geos               pkgs/main/win-64::geos-3.8.0-h33f27b4_0
#   proj               pkgs/main/win-64::proj-8.2.1-h5ed7ab8_0
#   pyproj             pkgs/main/win-64::pyproj-3.4.1-py39hb622704_0
#   pyshp              pkgs/main/noarch::pyshp-2.1.3-pyhd3eb1b0_0
#   shapely            pkgs/main/win-64::shapely-1.8.4-py39h9064783_0
#
# The following packages will be UPDATED:
#
#   conda                              22.11.1-py39haa95532_4 --> 23.1.0-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# geos-3.8.0           | 905 KB    |            |   0%
#
# cartopy-0.21.1       | 1.6 MB    |            |   0%
#
#
# pyproj-3.4.1         | 393 KB    |            |   0%
#
#
#
# proj-8.2.1           | 2.4 MB    |            |   0%
#
#
#
#
# shapely-1.8.4        | 364 KB    |            |   0%
#
#
#
#
#
# pyshp-2.1.3          | 37 KB     |            |   0%
#
#
#
#
#
#
# conda-23.1.0         | 946 KB    |            |   0%
#
#
# pyproj-3.4.1         | 393 KB    | 4          |   4%
# geos-3.8.0           | 905 KB    | 1          |   2%
#
# cartopy-0.21.1       | 1.6 MB    |            |   1%
#
#
#
#
# shapely-1.8.4        | 364 KB    | 4          |   4%
#
#
#
# proj-8.2.1           | 2.4 MB    |            |   1%
#
#
# pyproj-3.4.1         | 393 KB    | ######9    |  69%
#
# cartopy-0.21.1       | 1.6 MB    | ##9        |  30%
# geos-3.8.0           | 905 KB    | ###1       |  32%
#
#
#
#
# shapely-1.8.4        | 364 KB    | ########3  |  83%
#
#
#
# proj-8.2.1           | 2.4 MB    | 9          |  10%
#
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ####3      |  43%
#
#
#
#
#
#
# conda-23.1.0         | 946 KB    | 1          |   2%
#
#
# pyproj-3.4.1         | 393 KB    | ########## | 100%
#
#
#
# proj-8.2.1           | 2.4 MB    | ####9      |  49%
#
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ########4  |  85%
#
#
#
#
# shapely-1.8.4        | 364 KB    | ########## | 100%
# geos-3.8.0           | 905 KB    | ########## | 100%
# geos-3.8.0           | 905 KB    | ########## | 100%
#
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ########## | 100%
#
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ########## | 100%
#
# cartopy-0.21.1       | 1.6 MB    | ########## | 100%
#
# cartopy-0.21.1       | 1.6 MB    | ########## | 100%
#
#
#
#
#
#
# conda-23.1.0         | 946 KB    | ########## | 100%
#
#
#
# proj-8.2.1           | 2.4 MB    | ########## | 100%
#
#
#
# proj-8.2.1           | 2.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
